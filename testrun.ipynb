# %%
# !chmod +x run3.sh
# !./run3.sh
# Out:
# Starting initial training with SGD for corruption level c=0.15...
# logs/save_labelnoise0.15_resnet20
# corrupt: 0.15
# path: cifar10_0.15_corruptedlabel
# Files already downloaded and verified
# Start training:  0 -> 150
# current lr 1.00000e-01
# Epoch: [0][0/391]	Time 2.556 (2.556)	Data 0.268 (0.268)	Loss 3.7086 (3.7086)	Prec@1 5.469 (5.469)
# Epoch: [0][50/391]	Time 0.011 (0.062)	Data 0.001 (0.007)	Loss 2.1174 (2.4128)	Prec@1 23.438 (19.317)
# Epoch: [0][100/391]	Time 0.013 (0.038)	Data 0.001 (0.004)	Loss 1.9600 (2.2119)	Prec@1 27.344 (22.571)
# Epoch: [0][150/391]	Time 0.014 (0.030)	Data 0.002 (0.003)	Loss 1.9728 (2.1238)	Prec@1 31.250 (24.581)
# Epoch: [0][200/391]	Time 0.014 (0.026)	Data 0.002 (0.003)	Loss 1.7260 (2.0705)	Prec@1 38.281 (26.341)
# Epoch: [0][250/391]	Time 0.012 (0.023)	Data 0.001 (0.003)	Loss 1.8399 (2.0243)	Prec@1 32.812 (27.938)
# Epoch: [0][300/391]	Time 0.012 (0.022)	Data 0.001 (0.003)	Loss 1.6600 (1.9869)	Prec@1 40.625 (29.394)
# ...
