# %%
import matplotlib.pyplot as plt
import numpy as np
import os
# Extracted data
methods = ["PCA","SPCA", "TME","STE", "rTME(0.001)","rTME(0.01)","FMS",  "SFMS","cFMS","FT", "FMS (p=0.5)",  "SFMS (p=0.5)"]
dimensions = [3, 5, 6, 9, 12, 15, 20, 25]
corruption_levels = [0.01, 0.02, 0.05, 0.10, 0.15, 0.20, 0.30, 0.40, 0]

data = {
    "PCA": [
        [59.28, 79.12, 82.91, 87.99, 89.33, 90.56, 91.02, 91.46],
        [53.33, 75.05, 79.09, 86.56, 88.99, 90.26, 90.83, 91.09],
        [46.34, 75.9, 79.03, 85.63, 88.12, 89.3, 90.39, 90.42],
        [51.87, 75.49, 78.82, 86.02, 87.89, 88.67, 89.74, 90.23],
        [54.84, 73.27, 77.97, 84.13, 87.17, 88.26, 88.96, 89.14],
        [58.37, 75.76, 78.9, 84.64, 86.95, 87.77, 88.51, 88.89],
        [56.89, 72.34, 75.82, 82.71, 85.12, 85.94, 87.08, 87.43],
        [60.49, 75.23, 77.81, 81.06, 83.56, 85.05, 85.65, 85.84],
        [48.89, 78.67, 82.53, 87.49, 89.58, 90.96, 91.46, 91.77],
    ],
   
    "FMS": [
        [84.85, 85.82, 86.41, 87.44, 87.9, 91.32, 91.24, 91.38],
        [82.69, 83.9, 84.7, 86.01, 86.3, 91.22, 91.25, 91.11],
        [77.41, 79.66, 79.77, 81.01, 82.86, 90.57, 90.6, 90.58],
        [71.02, 66.77, 75.42, 78.84, 81.5, 90.54, 90.6, 90.41],
        [66.14, 69.0, 70.59, 74.58, 79.65, 89.62, 89.73, 89.65],
        [22.38, 68.55, 69.28, 73.26, 80.1, 89.05, 89.05, 89.2],
        [26.82, 58.91, 63.42, 70.15, 77.07, 82.49, 87.78, 87.82],
        [25.99, 63.12, 65.19, 73.16, 77.38, 79.75, 86.02, 86.16],
        [88.28, 89.02, 89.22, 89.06, 89.39, 91.81, 91.92, 91.78],
    ],
    
    "SFMS":[
    [84.77, 86.15, 86.77, 87.95, 91.27, 91.31, 91.25, 91.23],  # Corruption 0.01
    [82.3, 84.25, 85.37, 86.26, 91.28, 91.2, 91.21, 91.16],    # Corruption 0.02
    [77.34, 80.02, 80.21, 82.39, 90.67, 90.63, 90.65, 90.62],  # Corruption 0.05
    [71.5, 75.7, 76.74, 80.43, 90.46, 90.51, 90.5, 90.51],     # Corruption 0.10
    [66.02, 69.29, 72.42, 77.46, 83.53, 89.6, 89.74, 89.7],    # Corruption 0.15
    [22.92, 69.34, 70.02, 76.93, 83.0, 89.08, 89.08, 89.02],   # Corruption 0.20
    [26.42, 60.55, 64.24, 72.02, 78.95, 87.9, 87.8, 87.82],    # Corruption 0.30
    [26.29, 63.38, 65.06, 73.53, 77.51, 80.27, 85.99, 86.18],  # Corruption 0.40
    [88.28, 89.2, 89.19, 89.23, 91.76, 91.81, 91.88, 91.97],    # Corruption 0.00
    ],
    "FMS (p=0.5)":[
    [84.77, 85.6, 85.95, 84.65, 88.91, 91.31, 91.24, 91.06],   # Corruption 0.01
    [82.2, 83.15, 83.57, 89.03, 89.87, 90.7, 90.94, 91.17],    # Corruption 0.02
    [77.31, 79.42, 79.18, 89.26, 89.33, 90.15, 90.26, 90.03],  # Corruption 0.05
    [70.12, 73.28, 74.22, 56.83, 89.52, 89.93, 90.27, 89.85],  # Corruption 0.10
    [63.0, 68.78, 68.09, 75.11, 45.78, 89.29, 89.53, 89.38],   # Corruption 0.15
    [21.83, 25.33, 66.52, 86.7, 29.72, 88.94, 88.88, 88.24],   # Corruption 0.20
    [24.74, 58.79, 59.55, 85.07, 87.5, 87.16, 87.37, 86.92],   # Corruption 0.30
    [27.67, 58.83, 60.41, 84.8, 83.78, 84.37, 86.2, 85.37],    # Corruption 0.40
    [88.15, 88.98, 89.03, 89.53, 91.4, 91.33, 91.14, 91.63],    # Corruption 0.00
    ],
    
    "SFMS (p=0.5)":[
    [84.65, 85.76, 86.37, 87.37, 91.39, 91.33, 91.22, 91.52],  # Corruption 0.01
    [82.34, 83.33, 83.81, 84.96, 91.22, 91.11, 91.04, 90.89],  # Corruption 0.02
    [77.24, 79.5, 79.25, 78.14, 90.66, 90.61, 90.64, 90.63],   # Corruption 0.05
    [70.4, 73.78, 74.54, 74.16, 90.4, 90.45, 90.56, 90.02],    # Corruption 0.10
    [63.44, 69.12, 68.57, 67.86, 72.81, 89.59, 89.65, 89.46],  # Corruption 0.15
    [22.22, 67.65, 66.54, 24.54, 72.17, 89.11, 89.04, 89.07],  # Corruption 0.20
    [25.0, 59.23, 59.91, 28.81, 64.89, 87.84, 87.82, 87.59],   # Corruption 0.30
    [27.85, 59.31, 60.88, 34.78, 69.37, 70.68, 86.1, 85.8],    # Corruption 0.40
    [88.16, 88.91, 88.92, 88.89, 91.73, 91.82, 91.69, 91.67],  # Corruption 0.00
    ],
    "TME": [
        [84.95, 87.48, 87.82, 89.62, 90.45, 90.9, 91.26, 91.34],   # Corruption 0.01
        [83.31, 85.72, 86.26, 88.92, 90.43, 91.09, 91.12, 91.26],  # Corruption 0.02
        [79.97, 83.3, 84.84, 87.79, 89.47, 90.13, 90.36, 90.44],   # Corruption 0.05
        [70.76, 79.07, 81.52, 87.48, 89.13, 89.61, 90.1, 89.87],   # Corruption 0.10
        [68.97, 78.25, 80.55, 86.35, 88.13, 88.74, 89.4, 89.57],   # Corruption 0.15
        [68.97, 77.51, 79.23, 84.33, 86.67, 87.94, 88.77, 88.99],  # Corruption 0.20
        [59.66, 73.3, 77.84, 82.98, 85.52, 86.3, 87.69, 87.69],    # Corruption 0.30
        [55.33, 71.15, 75.32, 80.07, 82.83, 84.04, 85.72, 86.08],  # Corruption 0.40
        [89.32, 89.61, 89.59, 90.29, 91.29, 91.63, 91.8, 91.75]    # Corruption 0.00
    ],
    "STE": [
        [82.61, 84.54, 84.85, 85.7, 86.81, 91.38, 91.28, 91.14],   # Corruption 0.01
        [82.63, 83.3, 83.95, 83.34, 84.73, 91.38, 91.26, 91.19],   # Corruption 0.02
        [77.94, 78.4, 78.39, 79.17, 80.95, 90.57, 90.55, 90.58],   # Corruption 0.05
        [64.64, 67.77, 68.5, 68.75, 68.1, 90.21, 90.28, 90.13],    # Corruption 0.10
        [66.16, 56.1, 68.42, 62.91, 63.6, 89.69, 89.52, 89.25],    # Corruption 0.15
        [41.06, 38.22, 36.18, 35.89, 72.0, 72.18, 89.07, 89.05],   # Corruption 0.20
        [30.43, 34.08, 33.48, 35.25, 35.32, 68.64, 87.94, 87.65],  # Corruption 0.30
        [29.54, 38.8, 35.64, 62.76, 62.7, 67.6, 86.3, 86.09],      # Corruption 0.40
        [88.15, 88.74, 88.84, 88.9, 89.24, 91.8, 91.79, 91.77]     # Corruption 0.00
    ],
    "SPCA": [
        [84.23, 86.93, 87.45, 89.22, 90.16, 90.51, 90.84, 90.78],  # Corruption 0.01
        [83.06, 85.08, 85.84, 88.51, 90.01, 90.29, 90.48, 90.71],  # Corruption 0.02
        [77.95, 82.02, 83.54, 86.5, 88.41, 89.28, 89.58, 89.61],   # Corruption 0.05
        [70.76, 76.31, 78.66, 84.59, 86.49, 87.6, 88.34, 88.43],   # Corruption 0.10
        [66.75, 71.25, 78.46, 83.99, 85.89, 86.49, 87.5, 87.82],   # Corruption 0.15
        [65.79, 72.24, 73.9, 80.06, 84.12, 85.18, 86.31, 86.72],   # Corruption 0.20
        [57.42, 67.74, 73.49, 79.52, 83.32, 84.76, 86.06, 86.27],  # Corruption 0.30
        [52.33, 65.94, 69.09, 75.84, 78.05, 80.83, 83.01, 83.41],  # Corruption 0.40
        [87.96, 89.24, 89.34, 90.27, 91.06, 91.24, 91.52, 91.55]   # Corruption 0.00
    ],
    "rTME(r=0.001)": [
        [83.51, 85.11, 85.3, 85.4, 86.13, 86.42, 87.14, 88.04],
        [82.78, 83.78, 84.15, 83.86, 84.07, 84.41, 85.34, 86.73],
        [78.28, 79.15, 79.57, 79.91, 80.26, 80.81, 82.68, 84.63],
        [66.71, 68.92, 69.47, 73.17, 75.49, 75.89, 79.43, 81.78],
        [67.03, 61.47, 62.5, 72.34, 73.86, 77.28, 80.86, 82.54],
        [40.14, 69.3, 68.45, 69.31, 71.44, 73.26, 77.07, 80.54],
        [30.05, 60.56, 63.9, 67.47, 71.63, 73.65, 75.94, 78.57],
        [53.94, 59.79, 62.44, 66.49, 69.75, 72.26, 75.44, 76.57],
        [88.28, 88.97, 88.95, 88.88, 89.03, 89.0, 88.94, 89.93]
    ],
    "rTME(r=0.01)": [
        [83.21, 85.18, 85.16, 85.31, 86.16, 85.97, 86.91, 87.62],
        [82.7, 83.82, 84.15, 83.96, 84.1, 84.44, 85.63, 86.43],
        [77.98, 79.03, 79.65, 80.03, 80.44, 81.14, 83.04, 84.06],
        [66.35, 68.26, 68.81, 73.51, 75.72, 76.96, 79.95, 82.0],
        [66.71, 68.8, 62.28, 71.58, 73.67, 76.5, 81.0, 83.07],
        [40.55, 37.97, 69.08, 69.02, 72.02, 74.26, 77.47, 79.42],
        [29.89, 33.55, 33.56, 66.23, 70.22, 74.03, 78.66, 80.05],
        [27.42, 45.84, 60.6, 64.07, 69.67, 72.11, 76.58, 79.12],
        [88.09, 88.68, 88.9, 88.94, 89.09, 88.87, 88.89, 89.22]
    ],
    "Ft": [
        [83.15, 85.65, 85.58, 86.51, 87.58, 91.36, 91.38, 91.36],
        [82.95, 84.05, 84.24, 84.56, 85.79, 91.22, 91.2, 91.35],
        [78.43, 79.92, 80.58, 81.84, 83.46, 90.54, 90.5, 90.53],
        [66.59, 72.01, 72.16, 77.94, 82.35, 90.15, 90.15, 90.01],
        [67.34, 64.1, 64.38, 76.55, 81.14, 89.65, 89.61, 89.53],
        [63.06, 70.32, 70.97, 74.74, 78.33, 89.06, 89.05, 89.16],
        [29.78, 63.22, 68.72, 74.91, 78.62, 80.58, 87.92, 88.12],
        [48.5, 63.8, 67.24, 73.47, 75.64, 77.97, 86.41, 86.38],
        [88.27, 89.01, 89.21, 89.06, 89.39, 91.81, 91.93, 91.87]
    ],
    "cFMS": [
        [22.51, 59.6, 66.16, 80.32, 86.35, 91.48, 91.42, 91.35],
        [16.92, 51.83, 62.28, 75.99, 85.43, 91.3, 91.19, 91.35],
        [16.38, 59.65, 64.11, 78.38, 84.28, 90.49, 90.5, 90.52],
        [16.78, 41.31, 55.62, 77.7, 85.57, 90.13, 90.18, 89.94],
        [25.48, 56.3, 64.5, 77.82, 84.21, 89.59, 89.61, 89.54],
        [19.7, 56.8, 62.23, 75.44, 81.08, 88.95, 89.01, 89.1],
        [34.89, 63.45, 68.92, 76.72, 80.72, 87.91, 87.84, 88.06],
        [48.86, 66.61, 69.83, 75.16, 78.13, 80.57, 86.36, 86.41],
        [14.26, 56.84, 65.95, 78.62, 85.99, 91.75, 91.91, 91.78]
    ]
}

color_map = {
    "PCA": "red",
    "SPCA": "blue",
    "TME": "green",
    "STE": "orange",
    "rTME(r=0.001)": "purple",
    "rTME(r=0.01)": "brown",
    "FMS": "pink",
    "SFMS": "cyan",
    "cFMS": "magenta",
    "Ft": "olive",
    "FMS (p=0.5)": "lime",
    "SFMS (p=0.5)": "navy"
}
output_dir = "cifar10_results_plots"
os.makedirs(output_dir, exist_ok=True)

# Plot all methods for each corruption level
for i, corruption in enumerate(corruption_levels):
    plt.figure(figsize=(12, 8))
    for method in methods:
        if method in data:
            plt.plot(
                dimensions, 
                data[method][i], 
                marker='o', 
                label=method, 
                color=color_map[method]
            )

    plt.title(f"CIFAR-10 Results at Corruption Level {corruption}", fontsize=16)
    plt.xlabel("Reduced Dimensions", fontsize=14)
    plt.ylabel("Test Accuracy (%)", fontsize=14)
    plt.xticks(dimensions)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f"cifar10_results_corruption_{corruption}.png"),dpi=300)
    plt.close()
